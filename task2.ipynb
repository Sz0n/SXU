# %%
import numpy as np
import pandas as pd
moto = pd.read_csv('samochody1tys.csv')

# %%
#Wyświetlanie DataFrame "moto"
moto
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
#Wyświetlanie konkretnego rekordu
moto.iloc[499]
# Out:
# id                           499
# marka                        BMW
# model                         X4
# rok_produkcji               2017
# rodzaj_silnika            Diesel
# pojemnosc_silnika           1995
# przebieg                       2
# cena                      254000
# wojewodztwo          Małopolskie
# Name: 499, dtype: object

# %%
#Wyświetlanie pierwszych trzech rekordów 
moto.head(3)
# Out:
#    id   marka        model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0   0  Nissan  X-Trail III         2014.0         Diesel             1600.0
# 1   1     BMW       X1 E84         2012.0         Diesel             2000.0
# 2   2    Opel     Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 0  160000.0  75900.0    Dolnośląskie
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
#Wyświetlanie ostatnich trzech rekordów 
moto.tail(3)
# Out:
#       id    marka    model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 997  997  Renault    Modus         2004.0        Benzyna             1200.0
# 998  998     Audi    A3 8L         2000.0        Benzyna             1595.0
# 999  999    Volvo  XC 60 I         2016.0         Diesel             1969.0
#
#      przebieg      cena  wojewodztwo
# 997  168111.0   10900.0      Łódzkie
# 998  226500.0    5400.0  Małopolskie
# 999   13617.0  136900.0  Małopolskie

# %%
#Wyświetla rekordy z podanego przedziału
moto[499:503]
# Out:
#       id       marka     model  rok_produkcji rodzaj_silnika  \
# 499  499         BMW        X4         2017.0         Diesel
# 500  500  Volkswagen    Golf V         2007.0         Diesel
# 501  501        Opel  Meriva I         2004.0        Benzyna
# 502  502  Volkswagen    Beetle         2012.0        Benzyna
#
#      pojemnosc_silnika  przebieg      cena    wojewodztwo
# 499             1995.0       2.0  254000.0    Małopolskie
# 500             1896.0  171000.0   20900.0  Wielkopolskie
# 501             1800.0  153000.0   11900.0        Łódzkie
# 502             1390.0   35000.0   42900.0        Śląskie

# %%
#Wyświetla rekordy z podanego przedziału i tylko wskazane kolumny
moto.loc[499:525,['marka','model','rok_produkcji','przebieg','cena','wojewodztwo']]
# Out:
#              marka         model  rok_produkcji  przebieg      cena  \
# 499            BMW            X4         2017.0       2.0  254000.0
# 500     Volkswagen        Golf V         2007.0  171000.0   20900.0
# 501           Opel      Meriva I         2004.0  153000.0   11900.0
# 502     Volkswagen        Beetle         2012.0   35000.0   42900.0
# 503         Toyota    Avensis II         2007.0  190000.0   17900.0
# 504           Ford          EDGE         2017.0       1.0  208400.0
# 505  Mercedes-Benz  Klasa B W245         2007.0  108870.0   21900.0
# 506        Peugeot         307 I         2004.0  136000.0    9800.0
# 507        Renault     Laguna II         2001.0  264000.0    5900.0
# 508           Fiat       Tipo II         2017.0       1.0   44900.0
# 509        Renault     Scenic II         2005.0  202000.0   10600.0
# 510         Toyota    Avensis II         2003.0  164000.0   14300.0
# 511           Opel    Insignia A         2015.0  161199.0   51000.0
# ...

# %%
#Wyświetla tylko podaną kolumne
moto['marka']
# Out:
# 0          Nissan
# 1             BMW
# 2            Opel
# 3         Hyundai
# 4      Volkswagen
#           ...
# 995    Alfa Romeo
# 996         Škoda
# 997       Renault
# 998          Audi
# 999         Volvo
# Name: marka, Length: 1000, dtype: object

# %%
#Wyświetla liczbe rekordow o tej samej wartosci w podanej kolumnie 
moto['marka'].value_counts()
# Out:
# Opel             105
# Volkswagen        92
# Audi              70
# BMW               66
# Renault           59
# Mercedes-Benz     59
# Ford              59
# Toyota            49
# Peugeot           41
# Citroën           40
# Škoda             36
# Fiat              33
# Nissan            32
# Hyundai           31
# Honda             25
# Kia               25
# Volvo             24
# Mazda             21
# Seat              20
# Mitsubishi        18
# Suzuki            16
# Mini              11
# Chevrolet         11
# Lexus              7
# Jeep               6
# Dodge              5
# Land Rover         5
# Alfa Romeo         5
# Dacia              5
# Saab               3
# SsangYong          3
# Porsche            2
# Infiniti           2
# Jaguar             2
# Smart              2
# Daewoo             2
# Ligier             1
# Maserati           1
# Subaru             1
# Pontiac            1
# Daihatsu           1
# Lancia             1
# Chrysler           1
# ...

# %%
#Wyświetla rekordy które spełniają kryteria logiczne
moto[moto.cena < 10000]
# Out:
#       id    marka       model  rok_produkcji rodzaj_silnika  \
# 2      2     Opel    Zafira A         2004.0    Benzyna+CNG
# 7      7     Seat   Toledo II         2000.0        Benzyna
# 16    16     Ford  Mondeo Mk3         2003.0         Diesel
# 31    31     Fiat     Doblo I         2002.0        Benzyna
# 34    34  Citroën    Xsara II         2002.0        Benzyna
# ..   ...      ...         ...            ...            ...
# 943  943    Mazda       626 V         2001.0        Benzyna
# 965  965  Peugeot   Partner I         2003.0        Benzyna
# 975  975     Opel     Astra G         1998.0    Benzyna+LPG
# 984  984  Renault   Laguna II         2001.0        Benzyna
# 998  998     Audi       A3 8L         2000.0        Benzyna
#
#      pojemnosc_silnika  przebieg    cena     wojewodztwo
# 2               1600.0   99000.0  9800.0        Opolskie
# 7               1800.0  140700.0  8150.0       Pomorskie
# 16              2000.0  180000.0  7200.0     Małopolskie
# ...

# %%
#Wyświetla typ każdej kolumny
cars.dtypes
# Out:
# id                     int64
# marka                 object
# model                 object
# rok_produkcji        float64
# rodzaj_silnika        object
# pojemnosc_silnika    float64
# przebieg             float64
# cena                 float64
# wojewodztwo           object
# dtype: object

# %%
#Tworzy z kolumn wiersze
pd.melt(moto)
# Out:
#          variable        value
# 0              id            0
# 1              id            1
# 2              id            2
# 3              id            3
# 4              id            4
# ...           ...          ...
# 8995  wojewodztwo  Małopolskie
# 8996  wojewodztwo    Lubelskie
# 8997  wojewodztwo      Łódzkie
# 8998  wojewodztwo  Małopolskie
# 8999  wojewodztwo  Małopolskie
#
# [9000 rows x 2 columns]

# %%
#Zmiana nazwy kolumny
moto.rename(columns = {'rodzaj_silnika':'silnik'})
# Out:
#       id       marka        model  rok_produkcji       silnik  \
# 0      0      Nissan  X-Trail III         2014.0       Diesel
# 1      1         BMW       X1 E84         2012.0       Diesel
# 2      2        Opel     Zafira A         2004.0  Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0      Benzyna
# 4      4  Volkswagen           CC         2010.0       Diesel
# ..   ...         ...          ...            ...          ...
# 995  995  Alfa Romeo          159         2009.0       Diesel
# 996  996       Škoda     Fabia II         2012.0      Benzyna
# 997  997     Renault        Modus         2004.0      Benzyna
# 998  998        Audi        A3 8L         2000.0      Benzyna
# 999  999       Volvo      XC 60 I         2016.0       Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
#Sortowanie na podstawie wartosci podanej kolumny (ascending=False służy do sortowania malejąco)
moto.sort_values('cena')
#moto.sort_values('cena',ascending=False)
# Out:
#       id          marka                 model  rok_produkcji rodzaj_silnika  \
# 249  249         Daewoo                  Tico         2000.0        Benzyna
# 626  626     Mitsubishi              Colt CJ0         1997.0        Benzyna
# 497  497           Fiat                 Brava         1998.0        Benzyna
# 321  321     Volkswagen              Polo III         1998.0        Benzyna
# 487  487     Mitsubishi              Colt CJ0         2002.0        Benzyna
# ..   ...            ...                   ...            ...            ...
# 410  410            BMW        Seria 7 G11/12         2017.0        Hybryda
# 517  517           Audi                   RS7         2016.0        Benzyna
# 855  855     Land Rover  Range Rover Sport II         2016.0        Benzyna
# 586  586  Mercedes-Benz          Klasa G W463         2013.0        Benzyna
# 405  405  Mercedes-Benz               SL R231         2016.0        Benzyna
#
# ...

# %%
#Usuwanie wskazanych kolumn
moto.drop(columns=['pojemnosc_silnika','wojewodztwo'])
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  przebieg  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel  160000.0
# 1      1         BMW       X1 E84         2012.0         Diesel  149000.0
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG   99000.0
# 3      3     Hyundai        i10 I         2008.0        Benzyna   93000.0
# 4      4  Volkswagen           CC         2010.0         Diesel  127428.0
# ..   ...         ...          ...            ...            ...       ...
# 995  995  Alfa Romeo          159         2009.0         Diesel  182000.0
# 996  996       Škoda     Fabia II         2012.0        Benzyna   42700.0
# 997  997     Renault        Modus         2004.0        Benzyna  168111.0
# 998  998        Audi        A3 8L         2000.0        Benzyna  226500.0
# 999  999       Volvo      XC 60 I         2016.0         Diesel   13617.0
#
#          cena
# 0     75900.0
# 1     70900.0
# 2      9800.0
# 3     11900.0
# ...

# %%
#Wyświetla zakres indeksów
moto.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#Wyświetla kolumny
moto.columns
# Out:
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
#Wyświetla tablice której zawartość zostałą sprowadzona do wspolnego typu danych, w tym przypadku jest to Object
moto.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
#Wyświetla podstawowe statystyki dla kazdej kolumny(której zawartością są liczby) takie jak: ilosc, min, max, srednia itd.
moto.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
#Wyświetla posortowane dane, według wskazanych kolumn
cars.sort_values(by=["marka","model"])
# Out:
#       id       marka       model  rok_produkcji rodzaj_silnika  \
# 300  300  Alfa Romeo         147         2002.0        Benzyna
# 213  213  Alfa Romeo         156         2004.0         Diesel
# 370  370  Alfa Romeo         159         2007.0         Diesel
# 995  995  Alfa Romeo         159         2009.0         Diesel
# 705  705  Alfa Romeo      Spider         1995.0    Benzyna+LPG
# ..   ...         ...         ...            ...            ...
# 334  334       Škoda       RAPID         2017.0         Diesel
# 750  750       Škoda       RAPID         2016.0        Benzyna
# 159  159       Škoda  Superb III         2016.0         Diesel
# 295  295       Škoda  Superb III         2017.0         Diesel
# 957  957       Škoda  Superb III         2016.0        Benzyna
#
#      pojemnosc_silnika  przebieg      cena    wojewodztwo
# 300             2000.0  200000.0    4100.0      Lubelskie
# 213             1900.0  284000.0    6900.0      Lubelskie
# ...

# %%
#Wyświetla średnią każdej kolumny
moto.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
#Wyświetla srednią wartość każdego rekordu
moto.mean(1)
# Out:
# 0      47902.8
# 1      44782.6
# 2      22481.2
# 3      21602.2
# 4      36262.0
#         ...
# 995    44258.2
# 996    14461.6
# 997    36642.4
# 998    47298.6
# 999    31100.2
# Length: 1000, dtype: float64

# %%
#Wyświetla sume naszych rekordów, do każdego rekordu jest dodawana wartość poprzedniego
moto.apply(np.cumsum)
# Out:
#          id                                              marka  \
# 0         0                                             Nissan
# 1         1                                          NissanBMW
# 2         3                                      NissanBMWOpel
# 3         6                               NissanBMWOpelHyundai
# 4        10                     NissanBMWOpelHyundaiVolkswagen
# ..      ...                                                ...
# 995  495510  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 996  496506  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 997  497503  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 998  498501  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 999  499500  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
#
#                                                  model  rok_produkcji  \
# 0                                          X-Trail III         2014.0
# ...

# %%
#Wyświetla nasze dane po ich transpozycji
moto.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
#Ustawianie wartosci w podanej kolumnie
moto.loc[:,'model'] = np.array([0] * len(moto))
moto
# Out:
#       id       marka  model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0      0      Nissan      0         2014.0         Diesel             1600.0
# 1      1         BMW      0         2012.0         Diesel             2000.0
# 2      2        Opel      0         2004.0    Benzyna+CNG             1600.0
# 3      3     Hyundai      0         2008.0        Benzyna             1100.0
# 4      4  Volkswagen      0         2010.0         Diesel             1968.0
# ..   ...         ...    ...            ...            ...                ...
# 995  995  Alfa Romeo      0         2009.0         Diesel             2387.0
# 996  996       Škoda      0         2012.0        Benzyna             1200.0
# 997  997     Renault      0         2004.0        Benzyna             1200.0
# 998  998        Audi      0         2000.0        Benzyna             1595.0
# 999  999       Volvo      0         2016.0         Diesel             1969.0
#
#      przebieg      cena     wojewodztwo
# ...

# %%
#Ustawianie wartości kolumny według indexów
moto.iat[0,1] = 0
moto
# Out:
#       id       marka  model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0      0           0      0         2014.0         Diesel             1600.0
# 1      1         BMW      0         2012.0         Diesel             2000.0
# 2      2        Opel      0         2004.0    Benzyna+CNG             1600.0
# 3      3     Hyundai      0         2008.0        Benzyna             1100.0
# 4      4  Volkswagen      0         2010.0         Diesel             1968.0
# ..   ...         ...    ...            ...            ...                ...
# 995  995  Alfa Romeo      0         2009.0         Diesel             2387.0
# 996  996       Škoda      0         2012.0        Benzyna             1200.0
# 997  997     Renault      0         2004.0        Benzyna             1200.0
# 998  998        Audi      0         2000.0        Benzyna             1595.0
# 999  999       Volvo      0         2016.0         Diesel             1969.0
#
#      przebieg      cena     wojewodztwo
# ...

# %%
#Wyświetla jedno wymiarową tablice z danymi wskazanej kolumny
pd.Series(moto.marka,index=moto.id)
# Out:
# id
# 0          Nissan
# 1             BMW
# 2            Opel
# 3         Hyundai
# 4      Volkswagen
#           ...
# 995    Alfa Romeo
# 996         Škoda
# 997       Renault
# 998          Audi
# 999         Volvo
# Name: marka, Length: 1000, dtype: object

# %%
#Wyświetla posortowane kolumny według osi
moto.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika  model       marka   id      cena
# 0               1600.0      0      Nissan    0   75900.0
# 1               2000.0      0         BMW    1   70900.0
# 2               1600.0      0        Opel    2    9800.0
# ...

# %%
#Zwraca wartości true w tam gdzie zawartość jest NaN
pd.isna(moto)
# Out:
#         id  marka  model  rok_produkcji  rodzaj_silnika  pojemnosc_silnika  \
# 0    False  False  False          False           False              False
# 1    False  False  False          False           False              False
# 2    False  False  False          False           False              False
# 3    False  False  False          False           False              False
# 4    False  False  False          False           False              False
# ..     ...    ...    ...            ...             ...                ...
# 995  False  False  False          False           False              False
# 996  False  False  False          False           False              False
# 997  False  False  False          False           False              False
# 998  False  False  False          False           False              False
# 999  False  False  False          False           False              False
#
#      przebieg   cena  wojewodztwo
# ...
